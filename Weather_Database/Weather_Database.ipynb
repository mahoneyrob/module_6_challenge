# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create random longitude and latitudes
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 740

# %%
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime

# %%
#Testing to find keys and values
city = "San Francisco"
city_url = url + "&q=" + city.replace(" ","+")
city_weather1 = requests.get(city_url).json()
city_weather1
# Out:
# {'coord': {'lon': -122.4194, 'lat': 37.7749},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 71.2,
#   'feels_like': 71.4,
#   'temp_min': 59.83,
#   'temp_max': 91.78,
#   'pressure': 1016,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 263, 'gust': 8.99},
#  'clouds': {'all': 75},
#  'dt': 1632421631,
#  'sys': {'type': 2,
#   'id': 2007646,
#   'country': 'US',
#   'sunrise': 1632405516,
#   'sunset': 1632449114},
#  'timezone': -25200,
#  'id': 5391959,
#  'name': 'San Francisco',
#  'cod': 200}

# %%
#create empty list to hold weather data
city_data = []
#logging print
print("Beginning Data Retrieval        ")
print("--------------------------------")

#create counters
record_count = 1
set_count = 1

#loop through all cities
for i, city in enumerate(cities):
    #group cities in sets of 50
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create endpoint URL
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing record {record_count} of Set {set_count} | {city}")
    record_count += 1
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing record 1 of Set 1 | bredasdorp
# Processing record 2 of Set 1 | bluff
# Processing record 3 of Set 1 | port elizabeth
# Processing record 4 of Set 1 | altamira
# Processing record 5 of Set 1 | hermanus
# Processing record 6 of Set 1 | berlevag
# Processing record 7 of Set 1 | rikitea
# Processing record 8 of Set 1 | kodiak
# Processing record 9 of Set 1 | mataura
# Processing record 10 of Set 1 | qaanaaq
# Processing record 11 of Set 1 | namibe
# Processing record 12 of Set 1 | tasiilaq
# Processing record 13 of Set 1 | omboue
# Processing record 14 of Set 1 | east london
# Processing record 15 of Set 1 | vaini
# Processing record 16 of Set 1 | churapcha
# Processing record 17 of Set 1 | belushya guba
# Processing record 18 of Set 1 | sahrak
# Processing record 19 of Set 1 | yellowknife
# Processing record 20 of Set 1 | kenitra
# Processing record 21 of Set 1 | fort abbas
# Processing record 22 of Set 1 | makakilo city
# Processing record 23 of Set 1 | georgetown
# Processing record 24 of Set 1 | horodyshche
# Processing record 25 of Set 1 | pierre
# Processing record 26 of Set 1 | provideniya
# Processing record 27 of Set 1 | chuy
# Processing record 28 of Set 1 | port hedland
# Processing record 29 of Set 1 | wukari
# Processing record 30 of Set 1 | busselton
# Processing record 31 of Set 1 | maine-soroa
# Processing record 32 of Set 1 | upernavik
# Processing record 33 of Set 1 | talnakh
# Processing record 34 of Set 1 | narsaq
# Processing record 35 of Set 1 | atuona
# Processing record 36 of Set 1 | caravelas
# Processing record 37 of Set 1 | dikson
# Processing record 38 of Set 1 | hirara
# Processing record 39 of Set 1 | kamiiso
# Processing record 40 of Set 1 | new norfolk
# Processing record 41 of Set 1 | aklavik
# Processing record 42 of Set 1 | vaitupu
# Processing record 43 of Set 1 | fuxin
# Processing record 44 of Set 1 | praia
# Processing record 45 of Set 1 | goderich
# Processing record 46 of Set 1 | erfurt
# Processing record 47 of Set 1 | kuusankoski
# Processing record 48 of Set 1 | eureka
# Processing record 49 of Set 1 | kapaa
# Processing record 50 of Set 1 | mar del plata
# Processing record 1 of Set 2 | albany
# Processing record 2 of Set 2 | avarua
# Processing record 3 of Set 2 | hobart
# Processing record 4 of Set 2 | barentsburg
# Processing record 5 of Set 2 | winchester
# Processing record 6 of Set 2 | penzance
# Processing record 7 of Set 2 | mahebourg
# Processing record 8 of Set 2 | teya
# Processing record 9 of Set 2 | bengkulu
# Processing record 10 of Set 2 | cockburn town
# Processing record 11 of Set 2 | hilo
# Processing record 12 of Set 2 | jamestown
# Processing record 13 of Set 2 | illoqqortoormiut
# Processing record 14 of Set 2 | labelle
# Processing record 15 of Set 2 | roald
# Processing record 16 of Set 2 | chagda
# Processing record 17 of Set 2 | tuktoyaktuk
# Processing record 18 of Set 2 | castro
# Processing record 19 of Set 2 | egvekinot
# Processing record 20 of Set 2 | iringa
# Processing record 21 of Set 2 | deputatskiy
# Processing record 22 of Set 2 | safwah
# Processing record 23 of Set 2 | ilinskiy
# Processing record 24 of Set 2 | esperance
# Processing record 25 of Set 2 | port alfred
# Processing record 26 of Set 2 | usinsk
# Processing record 27 of Set 2 | paamiut
# Processing record 28 of Set 2 | la romana
# Processing record 29 of Set 2 | punta arenas
# Processing record 30 of Set 2 | arraial do cabo
# Processing record 31 of Set 2 | ruatoria
# Processing record 32 of Set 2 | saldanha
# Processing record 33 of Set 2 | parthenay
# Processing record 34 of Set 2 | lompoc
# Processing record 35 of Set 2 | ushuaia
# Processing record 36 of Set 2 | jardinopolis
# Processing record 37 of Set 2 | vila velha
# Processing record 38 of Set 2 | aswan
# Processing record 39 of Set 2 | puerto escondido
# Processing record 40 of Set 2 | barrow
# Processing record 41 of Set 2 | grindavik
# Processing record 42 of Set 2 | zonguldak
# Processing record 43 of Set 2 | port blair
# Processing record 44 of Set 2 | sobolevo
# Processing record 45 of Set 2 | varhaug
# Processing record 46 of Set 2 | yuzhnyy
# Processing record 47 of Set 2 | kirakira
# Processing record 48 of Set 2 | butaritari
# Processing record 49 of Set 2 | nacala
# Processing record 50 of Set 2 | gat
# Processing record 1 of Set 3 | lagoa
# Processing record 2 of Set 3 | ostrovnoy
# Processing record 3 of Set 3 | geraldton
# Processing record 4 of Set 3 | darnah
# Processing record 5 of Set 3 | fukue
# Processing record 6 of Set 3 | bambous virieux
# Processing record 7 of Set 3 | buta
# Processing record 8 of Set 3 | belyy yar
# Processing record 9 of Set 3 | nikolskoye
# Processing record 10 of Set 3 | pisco
# Processing record 11 of Set 3 | okhotsk
# Processing record 12 of Set 3 | chokurdakh
# Processing record 13 of Set 3 | khatanga
# Processing record 14 of Set 3 | parambu
# Processing record 15 of Set 3 | lata
# Processing record 16 of Set 3 | hendijan
# Processing record 17 of Set 3 | vestmannaeyjar
# Processing record 18 of Set 3 | hasaki
# Processing record 19 of Set 3 | cape town
# Processing record 20 of Set 3 | elat
# Processing record 21 of Set 3 | saskylakh
# Processing record 22 of Set 3 | nizhneyansk
# Processing record 23 of Set 3 | samarai
# Processing record 24 of Set 3 | norman wells
# Processing record 25 of Set 3 | acara
# Processing record 26 of Set 3 | zharkent
# Processing record 27 of Set 3 | kazachinskoye
# Processing record 28 of Set 3 | bathsheba
# Processing record 29 of Set 3 | saint-philippe
# Processing record 30 of Set 3 | eyl
# Processing record 31 of Set 3 | carnarvon
# Processing record 32 of Set 3 | hambantota
# Processing record 33 of Set 3 | puerto ayora
# Processing record 34 of Set 3 | college
# Processing record 35 of Set 3 | vila franca do campo
# Processing record 36 of Set 3 | kaoma
# Processing record 37 of Set 3 | saleaula
# Processing record 38 of Set 3 | meulaboh
# Processing record 39 of Set 3 | taolanaro
# Processing record 40 of Set 3 | beringovskiy
# Processing record 41 of Set 3 | sao miguel do oeste
# Processing record 42 of Set 3 | mucurapo
# Processing record 43 of Set 3 | bumba
# Processing record 44 of Set 3 | north charleston
# Processing record 45 of Set 3 | balaghat
# Processing record 46 of Set 3 | salalah
# Processing record 47 of Set 3 | waitati
# Processing record 48 of Set 3 | baykit
# Processing record 49 of Set 3 | punto fijo
# Processing record 50 of Set 3 | ambilobe
# Processing record 1 of Set 4 | nizhneudinsk
# Processing record 2 of Set 4 | airai
# Processing record 3 of Set 4 | tiksi
# Processing record 4 of Set 4 | sinnamary
# Processing record 5 of Set 4 | lavrentiya
# Processing record 6 of Set 4 | mount isa
# Processing record 7 of Set 4 | pangnirtung
# Processing record 8 of Set 4 | jiddah
# Processing record 9 of Set 4 | gananoque
# Processing record 10 of Set 4 | mys shmidta
# Processing record 11 of Set 4 | nanortalik
# Processing record 12 of Set 4 | ayr
# Processing record 13 of Set 4 | leningradskiy
# Processing record 14 of Set 4 | naze
# Processing record 15 of Set 4 | challapata
# Processing record 16 of Set 4 | majene
# Processing record 17 of Set 4 | hithadhoo
# Processing record 18 of Set 4 | kununurra
# Processing record 19 of Set 4 | hamilton
# Processing record 20 of Set 4 | nyahururu
# Processing record 21 of Set 4 | ivanivka
# Processing record 22 of Set 4 | aflu
# Processing record 23 of Set 4 | arlit
# Processing record 24 of Set 4 | amapa
# Processing record 25 of Set 4 | zyryanskoye
# Processing record 26 of Set 4 | marfino
# Processing record 27 of Set 4 | tonstad
# Processing record 28 of Set 4 | rawson
# Processing record 29 of Set 4 | tura
# Processing record 30 of Set 4 | areka
# Processing record 31 of Set 4 | sacramento
# Processing record 32 of Set 4 | ponta do sol
# Processing record 33 of Set 4 | santa maria da boa vista
# Processing record 34 of Set 4 | nyurba
# Processing record 35 of Set 4 | victoria
# Processing record 36 of Set 4 | tevaitoa
# Processing record 37 of Set 4 | kavaratti
# Processing record 38 of Set 4 | zemio
# Processing record 39 of Set 4 | sitka
# Processing record 40 of Set 4 | kushiro
# Processing record 41 of Set 4 | waddan
# Processing record 42 of Set 4 | ancud
# Processing record 43 of Set 4 | goias
# Processing record 44 of Set 4 | lyubinskiy
# Processing record 45 of Set 4 | camocim
# Processing record 46 of Set 4 | hailey
# Processing record 47 of Set 4 | san joaquin
# Processing record 48 of Set 4 | brighton
# Processing record 49 of Set 4 | yermish
# Processing record 50 of Set 4 | husavik
# Processing record 1 of Set 5 | mrirt
# Processing record 2 of Set 5 | mokhsogollokh
# Processing record 3 of Set 5 | palabuhanratu
# Processing record 4 of Set 5 | kampot
# Processing record 5 of Set 5 | aripuana
# Processing record 6 of Set 5 | labuhan
# Processing record 7 of Set 5 | amderma
# Processing record 8 of Set 5 | prescott
# Processing record 9 of Set 5 | atbasar
# Processing record 10 of Set 5 | dunedin
# Processing record 11 of Set 5 | severo-kurilsk
# Processing record 12 of Set 5 | portland
# Processing record 13 of Set 5 | nedjo
# Processing record 14 of Set 5 | noumea
# Processing record 15 of Set 5 | kahului
# Processing record 16 of Set 5 | meadow lake
# Processing record 17 of Set 5 | fortuna
# Processing record 18 of Set 5 | sentyabrskiy
# Processing record 19 of Set 5 | bonoua
# Processing record 20 of Set 5 | klyuchi
# Processing record 21 of Set 5 | urdzhar
# Processing record 22 of Set 5 | babu
# Processing record 23 of Set 5 | san patricio
# Processing record 24 of Set 5 | warqla
# Processing record 25 of Set 5 | iqaluit
# Processing record 26 of Set 5 | jiuquan
# Processing record 27 of Set 5 | thompson
# Processing record 28 of Set 5 | solnechnyy
# Processing record 29 of Set 5 | grand river south east
# Processing record 30 of Set 5 | keti bandar
# Processing record 31 of Set 5 | sao filipe
# Processing record 32 of Set 5 | namwala
# Processing record 33 of Set 5 | carauari
# Processing record 34 of Set 5 | yenagoa
# Processing record 35 of Set 5 | santa rita
# Processing record 36 of Set 5 | kandrian
# Processing record 37 of Set 5 | alice springs
# Processing record 38 of Set 5 | seropedica
# Processing record 39 of Set 5 | bucerias
# Processing record 40 of Set 5 | sterling
# Processing record 41 of Set 5 | antofagasta
# Processing record 42 of Set 5 | kieta
# Processing record 43 of Set 5 | tankhoy
# Processing record 44 of Set 5 | lebu
# Processing record 45 of Set 5 | richards bay
# Processing record 46 of Set 5 | dingle
# Processing record 47 of Set 5 | chernyshevskiy
# Processing record 48 of Set 5 | bergen
# Processing record 49 of Set 5 | eydhafushi
# Processing record 50 of Set 5 | kambove
# Processing record 1 of Set 6 | gornopravdinsk
# Processing record 2 of Set 6 | attawapiskat
# Processing record 3 of Set 6 | sar-e pul
# Processing record 4 of Set 6 | ilulissat
# Processing record 5 of Set 6 | bethel
# Processing record 6 of Set 6 | cabo san lucas
# Processing record 7 of Set 6 | santarem
# Processing record 8 of Set 6 | ola
# Processing record 9 of Set 6 | hay river
# Processing record 10 of Set 6 | rock sound
# Processing record 11 of Set 6 | mount gambier
# Processing record 12 of Set 6 | flinders
# Processing record 13 of Set 6 | morros
# Processing record 14 of Set 6 | skala fourkas
# Processing record 15 of Set 6 | champerico
# Processing record 16 of Set 6 | saint george
# Processing record 17 of Set 6 | vanavara
# Processing record 18 of Set 6 | praia da vitoria
# Processing record 19 of Set 6 | kenai
# Processing record 20 of Set 6 | alofi
# Processing record 21 of Set 6 | qaqortoq
# Processing record 22 of Set 6 | port hardy
# Processing record 23 of Set 6 | ribeira grande
# Processing record 24 of Set 6 | lasa
# Processing record 25 of Set 6 | progreso
# Processing record 26 of Set 6 | turukhansk
# Processing record 27 of Set 6 | akdepe
# Processing record 28 of Set 6 | wilmington
# Processing record 29 of Set 6 | houma
# Processing record 30 of Set 6 | ahipara
# Processing record 31 of Set 6 | shache
# Processing record 32 of Set 6 | codrington
# Processing record 33 of Set 6 | mayumba
# Processing record 34 of Set 6 | harer
# Processing record 35 of Set 6 | abonnema
# Processing record 36 of Set 6 | belmonte
# Processing record 37 of Set 6 | comodoro rivadavia
# Processing record 38 of Set 6 | lianzhou
# Processing record 39 of Set 6 | umm lajj
# Processing record 40 of Set 6 | ugoofaaru
# Processing record 41 of Set 6 | kefalos
# Processing record 42 of Set 6 | ust-ilimsk
# Processing record 43 of Set 6 | burley
# Processing record 44 of Set 6 | aranos
# Processing record 45 of Set 6 | vardo
# Processing record 46 of Set 6 | areia branca
# Processing record 47 of Set 6 | nome
# Processing record 48 of Set 6 | lebyazhye
# Processing record 49 of Set 6 | gzhatsk
# Processing record 50 of Set 6 | haputale
# Processing record 1 of Set 7 | mixtepec
# Processing record 2 of Set 7 | bubaque
# Processing record 3 of Set 7 | san ramon
# Processing record 4 of Set 7 | nieuw nickerie
# Processing record 5 of Set 7 | ballina
# Processing record 6 of Set 7 | kidal
# Processing record 7 of Set 7 | cabedelo
# Processing record 8 of Set 7 | lisala
# Processing record 9 of Set 7 | dukat
# Processing record 10 of Set 7 | kaitangata
# Processing record 11 of Set 7 | the valley
# Processing record 12 of Set 7 | umarkot
# Processing record 13 of Set 7 | bandarbeyla
# Processing record 14 of Set 7 | antalya
# Processing record 15 of Set 7 | sechura
# Processing record 16 of Set 7 | tambura
# Processing record 17 of Set 7 | manokwari
# Processing record 18 of Set 7 | ribeira brava
# Processing record 19 of Set 7 | longyearbyen
# Processing record 20 of Set 7 | strezhevoy
# Processing record 21 of Set 7 | pevek
# Processing record 22 of Set 7 | havre-saint-pierre
# Processing record 23 of Set 7 | andenes
# Processing record 24 of Set 7 | kadoma
# Processing record 25 of Set 7 | chapais
# Processing record 26 of Set 7 | shizunai
# Processing record 27 of Set 7 | guna
# Processing record 28 of Set 7 | chabahar
# Processing record 29 of Set 7 | faanui
# Processing record 30 of Set 7 | iguguno
# Processing record 31 of Set 7 | marsh harbour
# Processing record 32 of Set 7 | kautokeino
# Processing record 33 of Set 7 | mahajanga
# Processing record 34 of Set 7 | vestbygda
# Processing record 35 of Set 7 | saint-pierre
# Processing record 36 of Set 7 | lerwick
# Processing record 37 of Set 7 | tieli
# Processing record 38 of Set 7 | chino valley
# Processing record 39 of Set 7 | dawson creek
# Processing record 40 of Set 7 | baghdad
# Processing record 41 of Set 7 | ust-nera
# Processing record 42 of Set 7 | yerbogachen
# Processing record 43 of Set 7 | san cristobal
# Processing record 44 of Set 7 | porto novo
# Processing record 45 of Set 7 | kamina
# Processing record 46 of Set 7 | san policarpo
# Processing record 47 of Set 7 | koumac
# Processing record 48 of Set 7 | nishihara
# Processing record 49 of Set 7 | xiaoweizhai
# Processing record 50 of Set 7 | mayo
# Processing record 1 of Set 8 | atikokan
# Processing record 2 of Set 8 | saint-georges
# Processing record 3 of Set 8 | tsihombe
# Processing record 4 of Set 8 | atasu
# Processing record 5 of Set 8 | timizart
# Processing record 6 of Set 8 | olafsvik
# Processing record 7 of Set 8 | tecoanapa
# Processing record 8 of Set 8 | tahta
# Processing record 9 of Set 8 | clovis
# Processing record 10 of Set 8 | slawno
# Processing record 11 of Set 8 | sola
# Processing record 12 of Set 8 | padang
# Processing record 13 of Set 8 | tezu
# Processing record 14 of Set 8 | canmore
# Processing record 15 of Set 8 | acapulco
# Processing record 16 of Set 8 | dicabisagan
# Processing record 17 of Set 8 | umm durman
# Processing record 18 of Set 8 | gizo
# Processing record 19 of Set 8 | muroto
# Processing record 20 of Set 8 | la paz
# Processing record 21 of Set 8 | port lincoln
# Processing record 22 of Set 8 | orizona
# Processing record 23 of Set 8 | jinchang
# Processing record 24 of Set 8 | tuatapere
# Processing record 25 of Set 8 | alta floresta
# Processing record 26 of Set 8 | anadyr
# Processing record 27 of Set 8 | maromitsa
# Processing record 28 of Set 8 | cidreira
# Processing record 29 of Set 8 | la ligua
# Processing record 30 of Set 8 | acurenam
# Processing record 31 of Set 8 | asau
# Processing record 32 of Set 8 | sao miguel do araguaia
# Processing record 33 of Set 8 | hofn
# Processing record 34 of Set 8 | kirkland lake
# Processing record 35 of Set 8 | krasnoselkup
# Processing record 36 of Set 8 | melilla
# Processing record 37 of Set 8 | veraval
# Processing record 38 of Set 8 | bemidji
# Processing record 39 of Set 8 | maldonado
# Processing record 40 of Set 8 | tautira
# Processing record 41 of Set 8 | marck
# Processing record 42 of Set 8 | sioux lookout
# Processing record 43 of Set 8 | tilichiki
# Processing record 44 of Set 8 | berdigestyakh
# Processing record 45 of Set 8 | houston
# Processing record 46 of Set 8 | honiara
# Processing record 47 of Set 8 | lorengau
# Processing record 48 of Set 8 | xuanzhou
# Processing record 49 of Set 8 | bada
# Processing record 50 of Set 8 | ljungby
# Processing record 1 of Set 9 | umm kaddadah
# Processing record 2 of Set 9 | de-kastri
# Processing record 3 of Set 9 | rundu
# Processing record 4 of Set 9 | kropotkin
# Processing record 5 of Set 9 | tazovskiy
# Processing record 6 of Set 9 | teknaf
# Processing record 7 of Set 9 | bealanana
# Processing record 8 of Set 9 | itarema
# Processing record 9 of Set 9 | arman
# Processing record 10 of Set 9 | hervey bay
# Processing record 11 of Set 9 | kudahuvadhoo
# Processing record 12 of Set 9 | cayenne
# Processing record 13 of Set 9 | dubbo
# Processing record 14 of Set 9 | malanje
# Processing record 15 of Set 9 | catia la mar
# Processing record 16 of Set 9 | tumannyy
# Processing record 17 of Set 9 | yulara
# Processing record 18 of Set 9 | bozoum
# Processing record 19 of Set 9 | wloszczowa
# Processing record 20 of Set 9 | pueblo
# Processing record 21 of Set 9 | lengshuitan
# Processing record 22 of Set 9 | sorland
# Processing record 23 of Set 9 | stornoway
# Processing record 24 of Set 9 | surt
# Processing record 25 of Set 9 | yashan
# Processing record 26 of Set 9 | neiafu
# Processing record 27 of Set 9 | la ronge
# Processing record 28 of Set 9 | evensk
# Processing record 29 of Set 9 | bayonne
# Processing record 30 of Set 9 | enumclaw
# Processing record 31 of Set 9 | necochea
# Processing record 32 of Set 9 | bilibino
# Processing record 33 of Set 9 | lamar
# Processing record 34 of Set 9 | klaksvik
# Processing record 35 of Set 9 | pacific grove
# Processing record 36 of Set 9 | khasan
# Processing record 37 of Set 9 | battle creek
# Processing record 38 of Set 9 | saint-joseph
# Processing record 39 of Set 9 | yellapur
# Processing record 40 of Set 9 | blind river
# Processing record 41 of Set 9 | laguna
# Processing record 42 of Set 9 | plettenberg bay
# Processing record 43 of Set 9 | tidore
# Processing record 44 of Set 9 | luganville
# Processing record 45 of Set 9 | rioja
# Processing record 46 of Set 9 | burgersdorp
# Processing record 47 of Set 9 | thessalon
# Processing record 48 of Set 9 | montepulciano
# Processing record 49 of Set 9 | poya
# Processing record 50 of Set 9 | waipawa
# Processing record 1 of Set 10 | miracema do tocantins
# Processing record 2 of Set 10 | vilhena
# Processing record 3 of Set 10 | verkhnevilyuysk
# Processing record 4 of Set 10 | mocuba
# Processing record 5 of Set 10 | denpasar
# Processing record 6 of Set 10 | honningsvag
# Processing record 7 of Set 10 | verkhoyansk
# Processing record 8 of Set 10 | balimo
# Processing record 9 of Set 10 | iranshahr
# Processing record 10 of Set 10 | mumford
# Processing record 11 of Set 10 | montepuez
# Processing record 12 of Set 10 | rocha
# Processing record 13 of Set 10 | kasempa
# Processing record 14 of Set 10 | kalemie
# Processing record 15 of Set 10 | west wendover
# Processing record 16 of Set 10 | peniche
# Processing record 17 of Set 10 | flin flon
# Processing record 18 of Set 10 | villarrica
# Processing record 19 of Set 10 | merauke
# Processing record 20 of Set 10 | tateyama
# Processing record 21 of Set 10 | katsuura
# Processing record 22 of Set 10 | winslow
# Processing record 23 of Set 10 | san lawrenz
# Processing record 24 of Set 10 | jalu
# Processing record 25 of Set 10 | puri
# Processing record 26 of Set 10 | tarakan
# Processing record 27 of Set 10 | mareeba
# Processing record 28 of Set 10 | amahai
# Processing record 29 of Set 10 | sept-iles
# Processing record 30 of Set 10 | kapoeta
# Processing record 31 of Set 10 | touros
# Processing record 32 of Set 10 | skibbereen
# Processing record 33 of Set 10 | lakes entrance
# Processing record 34 of Set 10 | skage
# Processing record 35 of Set 10 | namatanai
# Processing record 36 of Set 10 | kharp
# Processing record 37 of Set 10 | batemans bay
# Processing record 38 of Set 10 | terrace bay
# Processing record 39 of Set 10 | ejea de los caballeros
# Processing record 40 of Set 10 | vila praia de ancora
# Processing record 41 of Set 10 | westerland
# Processing record 42 of Set 10 | tessalit
# Processing record 43 of Set 10 | ukiah
# Processing record 44 of Set 10 | san quintin
# Processing record 45 of Set 10 | jardim
# Processing record 46 of Set 10 | burayevo
# Processing record 47 of Set 10 | souillac
# Processing record 48 of Set 10 | aiken
# Processing record 49 of Set 10 | bolobo
# Processing record 50 of Set 10 | jumla
# Processing record 1 of Set 11 | drayton valley
# Processing record 2 of Set 11 | billings
# Processing record 3 of Set 11 | moron
# Processing record 4 of Set 11 | leh
# Processing record 5 of Set 11 | nara
# Processing record 6 of Set 11 | tazmalt
# Processing record 7 of Set 11 | moche
# Processing record 8 of Set 11 | ternate
# Processing record 9 of Set 11 | sasebo
# Processing record 10 of Set 11 | baruun-urt
# Processing record 11 of Set 11 | aykhal
# Processing record 12 of Set 11 | borba
# Processing record 13 of Set 11 | abu samrah
# Processing record 14 of Set 11 | benghazi
# Processing record 15 of Set 11 | tanout
# Processing record 16 of Set 11 | mackenzie
# Processing record 17 of Set 11 | riyadh
# Processing record 18 of Set 11 | besikduzu
# Processing record 19 of Set 11 | oranjestad
# Processing record 20 of Set 11 | abha
# Processing record 21 of Set 11 | cherskiy
# Processing record 22 of Set 11 | kutum
# Processing record 23 of Set 11 | fairbanks
# Processing record 24 of Set 11 | karratha
# Processing record 25 of Set 11 | brigantine
# Processing record 26 of Set 11 | minab
# Processing record 27 of Set 11 | king city
# Processing record 28 of Set 11 | komsomolets
# Processing record 29 of Set 11 | mason city
# Processing record 30 of Set 11 | gornozavodsk
# Processing record 31 of Set 11 | madaba
# Processing record 32 of Set 11 | tual
# Processing record 33 of Set 11 | los llanos de aridane
# Processing record 34 of Set 11 | jiayuguan
# Processing record 35 of Set 11 | fort smith
# Processing record 36 of Set 11 | helong
# Processing record 37 of Set 11 | zhigansk
# Processing record 38 of Set 11 | janauba
# Processing record 39 of Set 11 | fayaoue
# Processing record 40 of Set 11 | tchollire
# Processing record 41 of Set 11 | axim
# Processing record 42 of Set 11 | christchurch
# Processing record 43 of Set 11 | luderitz
# Processing record 44 of Set 11 | changde
# Processing record 45 of Set 11 | mporokoso
# Processing record 46 of Set 11 | nkowakowa
# Processing record 47 of Set 11 | florianopolis
# Processing record 48 of Set 11 | palana
# Processing record 49 of Set 11 | gijon
# Processing record 50 of Set 11 | lagos
# Processing record 1 of Set 12 | elko
# Processing record 2 of Set 12 | huntingdon
# Processing record 3 of Set 12 | pimentel
# Processing record 4 of Set 12 | kindu
# Processing record 5 of Set 12 | mugumu
# Processing record 6 of Set 12 | voh
# Processing record 7 of Set 12 | gallup
# Processing record 8 of Set 12 | biak
# Processing record 9 of Set 12 | buala
# Processing record 10 of Set 12 | kruisfontein
# Processing record 11 of Set 12 | yuzhno-kurilsk
# Processing record 12 of Set 12 | nemuro
# Processing record 13 of Set 12 | tomatlan
# Processing record 14 of Set 12 | ketchikan
# Processing record 15 of Set 12 | udachnyy
# Processing record 16 of Set 12 | buhl
# Processing record 17 of Set 12 | blonduos
# Processing record 18 of Set 12 | kulhudhuffushi
# Processing record 19 of Set 12 | boa esperanca
# Processing record 20 of Set 12 | kijang
# Processing record 21 of Set 12 | quatre cocos
# Processing record 22 of Set 12 | bagaha
# Processing record 23 of Set 12 | togur
# Processing record 24 of Set 12 | portmore
# Processing record 25 of Set 12 | kovur
# Processing record 26 of Set 12 | labutta
# Processing record 27 of Set 12 | kostyantynivka
# Processing record 28 of Set 12 | townsville
# Processing record 29 of Set 12 | chusovoy
# Processing record 30 of Set 12 | ewo
# Processing record 31 of Set 12 | sao desiderio
# Processing record 32 of Set 12 | matamoros
# Processing record 33 of Set 12 | torbay
# Processing record 34 of Set 12 | kupang
# Processing record 35 of Set 12 | glenwood springs
# Processing record 36 of Set 12 | launceston
# Processing record 37 of Set 12 | imbituba
# Processing record 38 of Set 12 | bara
# Processing record 39 of Set 12 | belaya gora
# Processing record 40 of Set 12 | lamu
# Processing record 41 of Set 12 | nibbar
# Processing record 42 of Set 12 | nuuk
# Processing record 43 of Set 12 | kontagora
# Processing record 44 of Set 12 | taltal
# Processing record 45 of Set 12 | odemira
# Processing record 46 of Set 12 | we
# Processing record 47 of Set 12 | scarborough
# Processing record 48 of Set 12 | yangambi
# Processing record 49 of Set 12 | sento se
# Processing record 50 of Set 12 | oxford
# Processing record 1 of Set 13 | vao
# Processing record 2 of Set 13 | adrar
# Processing record 3 of Set 13 | tabou
# Processing record 4 of Set 13 | pucallpa
# Processing record 5 of Set 13 | sangar
# Processing record 6 of Set 13 | cartagena
# Processing record 7 of Set 13 | kamenskoye
# Processing record 8 of Set 13 | gambela
# Processing record 9 of Set 13 | decatur
# Processing record 10 of Set 13 | aakirkeby
# Processing record 11 of Set 13 | velikiy ustyug
# Processing record 12 of Set 13 | upata
# Processing record 13 of Set 13 | aquiraz
# Processing record 14 of Set 13 | walvis bay
# Processing record 15 of Set 13 | mahoba
# Processing record 16 of Set 13 | dhidhdhoo
# Processing record 17 of Set 13 | takoradi
# Processing record 18 of Set 13 | akyab
# Processing record 19 of Set 13 | avera
# Processing record 20 of Set 13 | moerai
# Processing record 21 of Set 13 | khandyga
# Processing record 22 of Set 13 | poum
# Processing record 23 of Set 13 | inyonga
# Processing record 24 of Set 13 | geresk
# Processing record 25 of Set 13 | terekli-mekteb
# Processing record 26 of Set 13 | santa cruz
# Processing record 27 of Set 13 | la baule-escoublac
# Processing record 28 of Set 13 | chara
# Processing record 29 of Set 13 | tamandare
# Processing record 30 of Set 13 | karmala
# Processing record 31 of Set 13 | broome
# Processing record 32 of Set 13 | kulebaki
# Processing record 33 of Set 13 | wajir
# Processing record 34 of Set 13 | ahuimanu
# Processing record 35 of Set 13 | te anau
# Processing record 36 of Set 13 | solwezi
# Processing record 37 of Set 13 | nantucket
# Processing record 38 of Set 13 | edd
# Processing record 39 of Set 13 | shcherbynivka
# Processing record 40 of Set 13 | barstow
# Processing record 41 of Set 13 | xihe
# Processing record 42 of Set 13 | clyde river
# Processing record 43 of Set 13 | isangel
# Processing record 44 of Set 13 | faya
# Processing record 45 of Set 13 | sisimiut
# Processing record 46 of Set 13 | burgeo
# Processing record 47 of Set 13 | khorixas
# Processing record 48 of Set 13 | sao felix do xingu
# Processing record 49 of Set 13 | derzhavinsk
# Processing record 50 of Set 13 | truth or consequences
# Processing record 1 of Set 14 | port augusta
# Processing record 2 of Set 14 | makokou
# Processing record 3 of Set 14 | bilma
# Processing record 4 of Set 14 | jijiga
# Processing record 5 of Set 14 | san felipe
# Processing record 6 of Set 14 | gao
# Processing record 7 of Set 14 | roma
# Processing record 8 of Set 14 | tres coracoes
# Processing record 9 of Set 14 | shirokiy
# Processing record 10 of Set 14 | kattivakkam
# Processing record 11 of Set 14 | mogadishu
# Processing record 12 of Set 14 | chicama
# Processing record 13 of Set 14 | singkawang
# Processing record 14 of Set 14 | mazagao
# Processing record 15 of Set 14 | pathein
# Processing record 16 of Set 14 | todos santos
# Processing record 17 of Set 14 | yara
# Processing record 18 of Set 14 | san luis
# Processing record 19 of Set 14 | bay roberts
# Processing record 20 of Set 14 | nhulunbuy
# Processing record 21 of Set 14 | ogaminana
# Processing record 22 of Set 14 | dehui
# Processing record 23 of Set 14 | pandan
# Processing record 24 of Set 14 | karlskrona
# Processing record 25 of Set 14 | khandbari
# Processing record 26 of Set 14 | lahat
# Processing record 27 of Set 14 | kazalinsk
# Processing record 28 of Set 14 | boyolangu
# Processing record 29 of Set 14 | russell
# Processing record 30 of Set 14 | boende
# Processing record 31 of Set 14 | maragogi
# Processing record 32 of Set 14 | wawa
# Processing record 33 of Set 14 | general pico
# Processing record 34 of Set 14 | kavieng
# Processing record 35 of Set 14 | olinda
# Processing record 36 of Set 14 | garmsar
# Processing record 37 of Set 14 | tiznit
# Processing record 38 of Set 14 | kaduqli
# Processing record 39 of Set 14 | neryungri
# Processing record 40 of Set 14 | margate
# Processing record 41 of Set 14 | rungata
# Processing record 42 of Set 14 | gigmoto
# Processing record 43 of Set 14 | miranorte
# Processing record 44 of Set 14 | kampong thum
# Processing record 45 of Set 14 | smithers
# Processing record 46 of Set 14 | ranong
# Processing record 47 of Set 14 | ambon
# Processing record 48 of Set 14 | palmer
# Processing record 49 of Set 14 | schenectady
# Processing record 50 of Set 14 | maryville
# Processing record 1 of Set 15 | elizabethton
# Processing record 2 of Set 15 | luxor
# Processing record 3 of Set 15 | gamba
# Processing record 4 of Set 15 | chikoy
# Processing record 5 of Set 15 | shasta lake
# Processing record 6 of Set 15 | arona
# Processing record 7 of Set 15 | lokosovo
# Processing record 8 of Set 15 | vaitape
# Processing record 9 of Set 15 | nova olimpia
# Processing record 10 of Set 15 | fonte boa
# Processing record 11 of Set 15 | shiraz
# Processing record 12 of Set 15 | daru
# Processing record 13 of Set 15 | chilca
# Processing record 14 of Set 15 | tobane
# Processing record 15 of Set 15 | sakharovo
# Processing record 16 of Set 15 | sarangani
# Processing record 17 of Set 15 | guayanilla
# Processing record 18 of Set 15 | beloha
# Processing record 19 of Set 15 | mountain home
# Processing record 20 of Set 15 | suao
# Processing record 21 of Set 15 | luanda
# Processing record 22 of Set 15 | tarauaca
# Processing record 23 of Set 15 | kiama
# Processing record 24 of Set 15 | port hueneme
# Processing record 25 of Set 15 | camacha
# Processing record 26 of Set 15 | monroe
# Processing record 27 of Set 15 | abbeville
# Processing record 28 of Set 15 | ust-barguzin
# Processing record 29 of Set 15 | puerto ayacucho
# Processing record 30 of Set 15 | ruteng
# Processing record 31 of Set 15 | guerrero negro
# Processing record 32 of Set 15 | komsomolskiy
# Processing record 33 of Set 15 | sao joao da barra
# Processing record 34 of Set 15 | coihaique
# Processing record 35 of Set 15 | danville
# Processing record 36 of Set 15 | balkanabat
# Processing record 37 of Set 15 | bud
# Processing record 38 of Set 15 | thilogne
# Processing record 39 of Set 15 | takhli
# Processing record 40 of Set 15 | cervo

# %%
# run API with try loop
#create empty list to hold weather data
city_data = []
#logging print
print("Beginning Data Retrieval        ")
print("--------------------------------")

#create counters
record_count = 1
set_count = 1

#loop through all cities
for i, city in enumerate(cities):
    #group cities in sets of 50
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create endpoint URL
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
    
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description,
                          "Country": city_country,
                          "Date": city_date})
        
    except:
        print("city not found.  Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing record 1 of Set 1 | bredasdorp
# Processing record 2 of Set 1 | bluff
# Processing record 3 of Set 1 | port elizabeth
# Processing record 4 of Set 1 | altamira
# Processing record 5 of Set 1 | hermanus
# Processing record 6 of Set 1 | berlevag
# Processing record 7 of Set 1 | rikitea
# Processing record 8 of Set 1 | kodiak
# Processing record 9 of Set 1 | mataura
# Processing record 10 of Set 1 | qaanaaq
# Processing record 11 of Set 1 | namibe
# Processing record 12 of Set 1 | tasiilaq
# Processing record 13 of Set 1 | omboue
# Processing record 14 of Set 1 | east london
# Processing record 15 of Set 1 | vaini
# Processing record 16 of Set 1 | churapcha
# Processing record 17 of Set 1 | belushya guba
# city not found.  Skipping...
# Processing record 18 of Set 1 | sahrak
# city not found.  Skipping...
# Processing record 19 of Set 1 | yellowknife
# Processing record 20 of Set 1 | kenitra
# Processing record 21 of Set 1 | fort abbas
# Processing record 22 of Set 1 | makakilo city
# Processing record 23 of Set 1 | georgetown
# Processing record 24 of Set 1 | horodyshche
# Processing record 25 of Set 1 | pierre
# Processing record 26 of Set 1 | provideniya
# Processing record 27 of Set 1 | chuy
# Processing record 28 of Set 1 | port hedland
# Processing record 29 of Set 1 | wukari
# Processing record 30 of Set 1 | busselton
# Processing record 31 of Set 1 | maine-soroa
# Processing record 32 of Set 1 | upernavik
# Processing record 33 of Set 1 | talnakh
# Processing record 34 of Set 1 | narsaq
# Processing record 35 of Set 1 | atuona
# Processing record 36 of Set 1 | caravelas
# Processing record 37 of Set 1 | dikson
# Processing record 38 of Set 1 | hirara
# Processing record 39 of Set 1 | kamiiso
# Processing record 40 of Set 1 | new norfolk
# Processing record 41 of Set 1 | aklavik
# Processing record 42 of Set 1 | vaitupu
# city not found.  Skipping...
# Processing record 43 of Set 1 | fuxin
# Processing record 44 of Set 1 | praia
# Processing record 45 of Set 1 | goderich
# Processing record 46 of Set 1 | erfurt
# Processing record 47 of Set 1 | kuusankoski
# Processing record 48 of Set 1 | eureka
# Processing record 49 of Set 1 | kapaa
# Processing record 50 of Set 1 | mar del plata
# Processing record 1 of Set 2 | albany
# Processing record 2 of Set 2 | avarua
# Processing record 3 of Set 2 | hobart
# Processing record 4 of Set 2 | barentsburg
# city not found.  Skipping...
# Processing record 5 of Set 2 | winchester
# Processing record 6 of Set 2 | penzance
# Processing record 7 of Set 2 | mahebourg
# Processing record 8 of Set 2 | teya
# Processing record 9 of Set 2 | bengkulu
# Processing record 10 of Set 2 | cockburn town
# Processing record 11 of Set 2 | hilo
# Processing record 12 of Set 2 | jamestown
# Processing record 13 of Set 2 | illoqqortoormiut
# city not found.  Skipping...
# Processing record 14 of Set 2 | labelle
# Processing record 15 of Set 2 | roald
# Processing record 16 of Set 2 | chagda
# city not found.  Skipping...
# Processing record 17 of Set 2 | tuktoyaktuk
# Processing record 18 of Set 2 | castro
# Processing record 19 of Set 2 | egvekinot
# Processing record 20 of Set 2 | iringa
# Processing record 21 of Set 2 | deputatskiy
# Processing record 22 of Set 2 | safwah
# city not found.  Skipping...
# Processing record 23 of Set 2 | ilinskiy
# Processing record 24 of Set 2 | esperance
# Processing record 25 of Set 2 | port alfred
# Processing record 26 of Set 2 | usinsk
# Processing record 27 of Set 2 | paamiut
# Processing record 28 of Set 2 | la romana
# Processing record 29 of Set 2 | punta arenas
# Processing record 30 of Set 2 | arraial do cabo
# Processing record 31 of Set 2 | ruatoria
# city not found.  Skipping...
# Processing record 32 of Set 2 | saldanha
# Processing record 33 of Set 2 | parthenay
# Processing record 34 of Set 2 | lompoc
# Processing record 35 of Set 2 | ushuaia
# Processing record 36 of Set 2 | jardinopolis
# Processing record 37 of Set 2 | vila velha
# Processing record 38 of Set 2 | aswan
# Processing record 39 of Set 2 | puerto escondido
# Processing record 40 of Set 2 | barrow
# Processing record 41 of Set 2 | grindavik
# Processing record 42 of Set 2 | zonguldak
# Processing record 43 of Set 2 | port blair
# Processing record 44 of Set 2 | sobolevo
# Processing record 45 of Set 2 | varhaug
# Processing record 46 of Set 2 | yuzhnyy
# Processing record 47 of Set 2 | kirakira
# Processing record 48 of Set 2 | butaritari
# Processing record 49 of Set 2 | nacala
# Processing record 50 of Set 2 | gat
# Processing record 1 of Set 3 | lagoa
# Processing record 2 of Set 3 | ostrovnoy
# Processing record 3 of Set 3 | geraldton
# Processing record 4 of Set 3 | darnah
# Processing record 5 of Set 3 | fukue
# Processing record 6 of Set 3 | bambous virieux
# Processing record 7 of Set 3 | buta
# Processing record 8 of Set 3 | belyy yar
# Processing record 9 of Set 3 | nikolskoye
# Processing record 10 of Set 3 | pisco
# Processing record 11 of Set 3 | okhotsk
# Processing record 12 of Set 3 | chokurdakh
# Processing record 13 of Set 3 | khatanga
# Processing record 14 of Set 3 | parambu
# Processing record 15 of Set 3 | lata
# Processing record 16 of Set 3 | hendijan
# city not found.  Skipping...
# Processing record 17 of Set 3 | vestmannaeyjar
# Processing record 18 of Set 3 | hasaki
# Processing record 19 of Set 3 | cape town
# Processing record 20 of Set 3 | elat
# Processing record 21 of Set 3 | saskylakh
# Processing record 22 of Set 3 | nizhneyansk
# city not found.  Skipping...
# Processing record 23 of Set 3 | samarai
# Processing record 24 of Set 3 | norman wells
# Processing record 25 of Set 3 | acara
# Processing record 26 of Set 3 | zharkent
# Processing record 27 of Set 3 | kazachinskoye
# Processing record 28 of Set 3 | bathsheba
# Processing record 29 of Set 3 | saint-philippe
# Processing record 30 of Set 3 | eyl
# Processing record 31 of Set 3 | carnarvon
# Processing record 32 of Set 3 | hambantota
# Processing record 33 of Set 3 | puerto ayora
# Processing record 34 of Set 3 | college
# Processing record 35 of Set 3 | vila franca do campo
# Processing record 36 of Set 3 | kaoma
# Processing record 37 of Set 3 | saleaula
# city not found.  Skipping...
# Processing record 38 of Set 3 | meulaboh
# Processing record 39 of Set 3 | taolanaro
# city not found.  Skipping...
# Processing record 40 of Set 3 | beringovskiy
# Processing record 41 of Set 3 | sao miguel do oeste
# city not found.  Skipping...
# Processing record 42 of Set 3 | mucurapo
# Processing record 43 of Set 3 | bumba
# Processing record 44 of Set 3 | north charleston
# Processing record 45 of Set 3 | balaghat
# Processing record 46 of Set 3 | salalah
# Processing record 47 of Set 3 | waitati
# Processing record 48 of Set 3 | baykit
# Processing record 49 of Set 3 | punto fijo
# Processing record 50 of Set 3 | ambilobe
# Processing record 1 of Set 4 | nizhneudinsk
# Processing record 2 of Set 4 | airai
# Processing record 3 of Set 4 | tiksi
# Processing record 4 of Set 4 | sinnamary
# Processing record 5 of Set 4 | lavrentiya
# Processing record 6 of Set 4 | mount isa
# Processing record 7 of Set 4 | pangnirtung
# Processing record 8 of Set 4 | jiddah
# city not found.  Skipping...
# Processing record 9 of Set 4 | gananoque
# Processing record 10 of Set 4 | mys shmidta
# city not found.  Skipping...
# Processing record 11 of Set 4 | nanortalik
# Processing record 12 of Set 4 | ayr
# Processing record 13 of Set 4 | leningradskiy
# Processing record 14 of Set 4 | naze
# Processing record 15 of Set 4 | challapata
# Processing record 16 of Set 4 | majene
# Processing record 17 of Set 4 | hithadhoo
# Processing record 18 of Set 4 | kununurra
# Processing record 19 of Set 4 | hamilton
# Processing record 20 of Set 4 | nyahururu
# Processing record 21 of Set 4 | ivanivka
# Processing record 22 of Set 4 | aflu
# city not found.  Skipping...
# Processing record 23 of Set 4 | arlit
# Processing record 24 of Set 4 | amapa
# Processing record 25 of Set 4 | zyryanskoye
# Processing record 26 of Set 4 | marfino
# Processing record 27 of Set 4 | tonstad
# Processing record 28 of Set 4 | rawson
# Processing record 29 of Set 4 | tura
# Processing record 30 of Set 4 | areka
# Processing record 31 of Set 4 | sacramento
# Processing record 32 of Set 4 | ponta do sol
# Processing record 33 of Set 4 | santa maria da boa vista
# Processing record 34 of Set 4 | nyurba
# Processing record 35 of Set 4 | victoria
# Processing record 36 of Set 4 | tevaitoa
# Processing record 37 of Set 4 | kavaratti
# Processing record 38 of Set 4 | zemio
# Processing record 39 of Set 4 | sitka
# Processing record 40 of Set 4 | kushiro
# Processing record 41 of Set 4 | waddan
# Processing record 42 of Set 4 | ancud
# Processing record 43 of Set 4 | goias
# Processing record 44 of Set 4 | lyubinskiy
# Processing record 45 of Set 4 | camocim
# Processing record 46 of Set 4 | hailey
# Processing record 47 of Set 4 | san joaquin
# Processing record 48 of Set 4 | brighton
# Processing record 49 of Set 4 | yermish
# Processing record 50 of Set 4 | husavik
# Processing record 1 of Set 5 | mrirt
# city not found.  Skipping...
# Processing record 2 of Set 5 | mokhsogollokh
# Processing record 3 of Set 5 | palabuhanratu
# city not found.  Skipping...
# Processing record 4 of Set 5 | kampot
# Processing record 5 of Set 5 | aripuana
# Processing record 6 of Set 5 | labuhan
# Processing record 7 of Set 5 | amderma
# city not found.  Skipping...
# Processing record 8 of Set 5 | prescott
# Processing record 9 of Set 5 | atbasar
# Processing record 10 of Set 5 | dunedin
# Processing record 11 of Set 5 | severo-kurilsk
# Processing record 12 of Set 5 | portland
# Processing record 13 of Set 5 | nedjo
# Processing record 14 of Set 5 | noumea
# Processing record 15 of Set 5 | kahului
# Processing record 16 of Set 5 | meadow lake
# Processing record 17 of Set 5 | fortuna
# Processing record 18 of Set 5 | sentyabrskiy
# city not found.  Skipping...
# Processing record 19 of Set 5 | bonoua
# Processing record 20 of Set 5 | klyuchi
# Processing record 21 of Set 5 | urdzhar
# city not found.  Skipping...
# Processing record 22 of Set 5 | babu
# Processing record 23 of Set 5 | san patricio
# Processing record 24 of Set 5 | warqla
# city not found.  Skipping...
# Processing record 25 of Set 5 | iqaluit
# Processing record 26 of Set 5 | jiuquan
# Processing record 27 of Set 5 | thompson
# Processing record 28 of Set 5 | solnechnyy
# Processing record 29 of Set 5 | grand river south east
# city not found.  Skipping...
# Processing record 30 of Set 5 | keti bandar
# Processing record 31 of Set 5 | sao filipe
# Processing record 32 of Set 5 | namwala
# Processing record 33 of Set 5 | carauari
# Processing record 34 of Set 5 | yenagoa
# Processing record 35 of Set 5 | santa rita
# Processing record 36 of Set 5 | kandrian
# Processing record 37 of Set 5 | alice springs
# Processing record 38 of Set 5 | seropedica
# Processing record 39 of Set 5 | bucerias
# Processing record 40 of Set 5 | sterling
# Processing record 41 of Set 5 | antofagasta
# Processing record 42 of Set 5 | kieta
# Processing record 43 of Set 5 | tankhoy
# Processing record 44 of Set 5 | lebu
# Processing record 45 of Set 5 | richards bay
# Processing record 46 of Set 5 | dingle
# Processing record 47 of Set 5 | chernyshevskiy
# Processing record 48 of Set 5 | bergen
# Processing record 49 of Set 5 | eydhafushi
# Processing record 50 of Set 5 | kambove
# Processing record 1 of Set 6 | gornopravdinsk
# Processing record 2 of Set 6 | attawapiskat
# city not found.  Skipping...
# Processing record 3 of Set 6 | sar-e pul
# Processing record 4 of Set 6 | ilulissat
# Processing record 5 of Set 6 | bethel
# Processing record 6 of Set 6 | cabo san lucas
# Processing record 7 of Set 6 | santarem
# Processing record 8 of Set 6 | ola
# Processing record 9 of Set 6 | hay river
# Processing record 10 of Set 6 | rock sound
# Processing record 11 of Set 6 | mount gambier
# Processing record 12 of Set 6 | flinders
# Processing record 13 of Set 6 | morros
# Processing record 14 of Set 6 | skala fourkas
# Processing record 15 of Set 6 | champerico
# Processing record 16 of Set 6 | saint george
# Processing record 17 of Set 6 | vanavara
# Processing record 18 of Set 6 | praia da vitoria
# Processing record 19 of Set 6 | kenai
# Processing record 20 of Set 6 | alofi
# Processing record 21 of Set 6 | qaqortoq
# Processing record 22 of Set 6 | port hardy
# Processing record 23 of Set 6 | ribeira grande
# Processing record 24 of Set 6 | lasa
# Processing record 25 of Set 6 | progreso
# Processing record 26 of Set 6 | turukhansk
# Processing record 27 of Set 6 | akdepe
# Processing record 28 of Set 6 | wilmington
# Processing record 29 of Set 6 | houma
# Processing record 30 of Set 6 | ahipara
# Processing record 31 of Set 6 | shache
# Processing record 32 of Set 6 | codrington
# Processing record 33 of Set 6 | mayumba
# Processing record 34 of Set 6 | harer
# Processing record 35 of Set 6 | abonnema
# Processing record 36 of Set 6 | belmonte
# Processing record 37 of Set 6 | comodoro rivadavia
# Processing record 38 of Set 6 | lianzhou
# Processing record 39 of Set 6 | umm lajj
# Processing record 40 of Set 6 | ugoofaaru
# Processing record 41 of Set 6 | kefalos
# Processing record 42 of Set 6 | ust-ilimsk
# Processing record 43 of Set 6 | burley
# Processing record 44 of Set 6 | aranos
# Processing record 45 of Set 6 | vardo
# Processing record 46 of Set 6 | areia branca
# Processing record 47 of Set 6 | nome
# Processing record 48 of Set 6 | lebyazhye
# Processing record 49 of Set 6 | gzhatsk
# city not found.  Skipping...
# Processing record 50 of Set 6 | haputale
# Processing record 1 of Set 7 | mixtepec
# city not found.  Skipping...
# Processing record 2 of Set 7 | bubaque
# Processing record 3 of Set 7 | san ramon
# Processing record 4 of Set 7 | nieuw nickerie
# Processing record 5 of Set 7 | ballina
# Processing record 6 of Set 7 | kidal
# Processing record 7 of Set 7 | cabedelo
# Processing record 8 of Set 7 | lisala
# Processing record 9 of Set 7 | dukat
# Processing record 10 of Set 7 | kaitangata
# Processing record 11 of Set 7 | the valley
# Processing record 12 of Set 7 | umarkot
# Processing record 13 of Set 7 | bandarbeyla
# Processing record 14 of Set 7 | antalya
# Processing record 15 of Set 7 | sechura
# Processing record 16 of Set 7 | tambura
# Processing record 17 of Set 7 | manokwari
# Processing record 18 of Set 7 | ribeira brava
# Processing record 19 of Set 7 | longyearbyen
# Processing record 20 of Set 7 | strezhevoy
# Processing record 21 of Set 7 | pevek
# Processing record 22 of Set 7 | havre-saint-pierre
# Processing record 23 of Set 7 | andenes
# Processing record 24 of Set 7 | kadoma
# Processing record 25 of Set 7 | chapais
# Processing record 26 of Set 7 | shizunai
# Processing record 27 of Set 7 | guna
# Processing record 28 of Set 7 | chabahar
# Processing record 29 of Set 7 | faanui
# Processing record 30 of Set 7 | iguguno
# Processing record 31 of Set 7 | marsh harbour
# Processing record 32 of Set 7 | kautokeino
# Processing record 33 of Set 7 | mahajanga
# Processing record 34 of Set 7 | vestbygda
# city not found.  Skipping...
# Processing record 35 of Set 7 | saint-pierre
# Processing record 36 of Set 7 | lerwick
# Processing record 37 of Set 7 | tieli
# Processing record 38 of Set 7 | chino valley
# Processing record 39 of Set 7 | dawson creek
# Processing record 40 of Set 7 | baghdad
# Processing record 41 of Set 7 | ust-nera
# Processing record 42 of Set 7 | yerbogachen
# Processing record 43 of Set 7 | san cristobal
# Processing record 44 of Set 7 | porto novo
# Processing record 45 of Set 7 | kamina
# Processing record 46 of Set 7 | san policarpo
# Processing record 47 of Set 7 | koumac
# Processing record 48 of Set 7 | nishihara
# Processing record 49 of Set 7 | xiaoweizhai
# Processing record 50 of Set 7 | mayo
# Processing record 1 of Set 8 | atikokan
# Processing record 2 of Set 8 | saint-georges
# Processing record 3 of Set 8 | tsihombe
# city not found.  Skipping...
# Processing record 4 of Set 8 | atasu
# Processing record 5 of Set 8 | timizart
# Processing record 6 of Set 8 | olafsvik
# Processing record 7 of Set 8 | tecoanapa
# Processing record 8 of Set 8 | tahta
# Processing record 9 of Set 8 | clovis
# Processing record 10 of Set 8 | slawno
# Processing record 11 of Set 8 | sola
# Processing record 12 of Set 8 | padang
# Processing record 13 of Set 8 | tezu
# Processing record 14 of Set 8 | canmore
# Processing record 15 of Set 8 | acapulco
# Processing record 16 of Set 8 | dicabisagan
# Processing record 17 of Set 8 | umm durman
# city not found.  Skipping...
# Processing record 18 of Set 8 | gizo
# Processing record 19 of Set 8 | muroto
# Processing record 20 of Set 8 | la paz
# Processing record 21 of Set 8 | port lincoln
# Processing record 22 of Set 8 | orizona
# Processing record 23 of Set 8 | jinchang
# Processing record 24 of Set 8 | tuatapere
# Processing record 25 of Set 8 | alta floresta
# Processing record 26 of Set 8 | anadyr
# Processing record 27 of Set 8 | maromitsa
# Processing record 28 of Set 8 | cidreira
# Processing record 29 of Set 8 | la ligua
# Processing record 30 of Set 8 | acurenam
# Processing record 31 of Set 8 | asau
# Processing record 32 of Set 8 | sao miguel do araguaia
# Processing record 33 of Set 8 | hofn
# Processing record 34 of Set 8 | kirkland lake
# Processing record 35 of Set 8 | krasnoselkup
# Processing record 36 of Set 8 | melilla
# Processing record 37 of Set 8 | veraval
# Processing record 38 of Set 8 | bemidji
# Processing record 39 of Set 8 | maldonado
# Processing record 40 of Set 8 | tautira
# Processing record 41 of Set 8 | marck
# Processing record 42 of Set 8 | sioux lookout
# Processing record 43 of Set 8 | tilichiki
# Processing record 44 of Set 8 | berdigestyakh
# Processing record 45 of Set 8 | houston
# Processing record 46 of Set 8 | honiara
# Processing record 47 of Set 8 | lorengau
# Processing record 48 of Set 8 | xuanzhou
# Processing record 49 of Set 8 | bada
# Processing record 50 of Set 8 | ljungby
# Processing record 1 of Set 9 | umm kaddadah
# Processing record 2 of Set 9 | de-kastri
# Processing record 3 of Set 9 | rundu
# Processing record 4 of Set 9 | kropotkin
# Processing record 5 of Set 9 | tazovskiy
# Processing record 6 of Set 9 | teknaf
# Processing record 7 of Set 9 | bealanana
# Processing record 8 of Set 9 | itarema
# Processing record 9 of Set 9 | arman
# Processing record 10 of Set 9 | hervey bay
# Processing record 11 of Set 9 | kudahuvadhoo
# Processing record 12 of Set 9 | cayenne
# Processing record 13 of Set 9 | dubbo
# Processing record 14 of Set 9 | malanje
# Processing record 15 of Set 9 | catia la mar
# Processing record 16 of Set 9 | tumannyy
# city not found.  Skipping...
# Processing record 17 of Set 9 | yulara
# Processing record 18 of Set 9 | bozoum
# Processing record 19 of Set 9 | wloszczowa
# Processing record 20 of Set 9 | pueblo
# Processing record 21 of Set 9 | lengshuitan
# Processing record 22 of Set 9 | sorland
# Processing record 23 of Set 9 | stornoway
# Processing record 24 of Set 9 | surt
# Processing record 25 of Set 9 | yashan
# Processing record 26 of Set 9 | neiafu
# Processing record 27 of Set 9 | la ronge
# Processing record 28 of Set 9 | evensk
# Processing record 29 of Set 9 | bayonne
# Processing record 30 of Set 9 | enumclaw
# Processing record 31 of Set 9 | necochea
# Processing record 32 of Set 9 | bilibino
# Processing record 33 of Set 9 | lamar
# Processing record 34 of Set 9 | klaksvik
# Processing record 35 of Set 9 | pacific grove
# Processing record 36 of Set 9 | khasan
# Processing record 37 of Set 9 | battle creek
# Processing record 38 of Set 9 | saint-joseph
# Processing record 39 of Set 9 | yellapur
# Processing record 40 of Set 9 | blind river
# Processing record 41 of Set 9 | laguna
# Processing record 42 of Set 9 | plettenberg bay
# Processing record 43 of Set 9 | tidore
# city not found.  Skipping...
# Processing record 44 of Set 9 | luganville
# Processing record 45 of Set 9 | rioja
# Processing record 46 of Set 9 | burgersdorp
# Processing record 47 of Set 9 | thessalon
# Processing record 48 of Set 9 | montepulciano
# Processing record 49 of Set 9 | poya
# Processing record 50 of Set 9 | waipawa
# Processing record 1 of Set 10 | miracema do tocantins
# Processing record 2 of Set 10 | vilhena
# Processing record 3 of Set 10 | verkhnevilyuysk
# Processing record 4 of Set 10 | mocuba
# Processing record 5 of Set 10 | denpasar
# Processing record 6 of Set 10 | honningsvag
# Processing record 7 of Set 10 | verkhoyansk
# Processing record 8 of Set 10 | balimo
# city not found.  Skipping...
# Processing record 9 of Set 10 | iranshahr
# Processing record 10 of Set 10 | mumford
# Processing record 11 of Set 10 | montepuez
# Processing record 12 of Set 10 | rocha
# Processing record 13 of Set 10 | kasempa
# Processing record 14 of Set 10 | kalemie
# Processing record 15 of Set 10 | west wendover
# Processing record 16 of Set 10 | peniche
# Processing record 17 of Set 10 | flin flon
# Processing record 18 of Set 10 | villarrica
# Processing record 19 of Set 10 | merauke
# Processing record 20 of Set 10 | tateyama
# Processing record 21 of Set 10 | katsuura
# Processing record 22 of Set 10 | winslow
# Processing record 23 of Set 10 | san lawrenz
# Processing record 24 of Set 10 | jalu
# Processing record 25 of Set 10 | puri
# Processing record 26 of Set 10 | tarakan
# Processing record 27 of Set 10 | mareeba
# Processing record 28 of Set 10 | amahai
# Processing record 29 of Set 10 | sept-iles
# Processing record 30 of Set 10 | kapoeta
# Processing record 31 of Set 10 | touros
# Processing record 32 of Set 10 | skibbereen
# Processing record 33 of Set 10 | lakes entrance
# Processing record 34 of Set 10 | skage
# city not found.  Skipping...
# Processing record 35 of Set 10 | namatanai
# Processing record 36 of Set 10 | kharp
# Processing record 37 of Set 10 | batemans bay
# Processing record 38 of Set 10 | terrace bay
# Processing record 39 of Set 10 | ejea de los caballeros
# Processing record 40 of Set 10 | vila praia de ancora
# Processing record 41 of Set 10 | westerland
# Processing record 42 of Set 10 | tessalit
# Processing record 43 of Set 10 | ukiah
# Processing record 44 of Set 10 | san quintin
# Processing record 45 of Set 10 | jardim
# Processing record 46 of Set 10 | burayevo
# Processing record 47 of Set 10 | souillac
# Processing record 48 of Set 10 | aiken
# Processing record 49 of Set 10 | bolobo
# Processing record 50 of Set 10 | jumla
# Processing record 1 of Set 11 | drayton valley
# Processing record 2 of Set 11 | billings
# Processing record 3 of Set 11 | moron
# Processing record 4 of Set 11 | leh
# Processing record 5 of Set 11 | nara
# Processing record 6 of Set 11 | tazmalt
# Processing record 7 of Set 11 | moche
# Processing record 8 of Set 11 | ternate
# Processing record 9 of Set 11 | sasebo
# Processing record 10 of Set 11 | baruun-urt
# Processing record 11 of Set 11 | aykhal
# Processing record 12 of Set 11 | borba
# Processing record 13 of Set 11 | abu samrah
# Processing record 14 of Set 11 | benghazi
# Processing record 15 of Set 11 | tanout
# Processing record 16 of Set 11 | mackenzie
# Processing record 17 of Set 11 | riyadh
# Processing record 18 of Set 11 | besikduzu
# Processing record 19 of Set 11 | oranjestad
# Processing record 20 of Set 11 | abha
# Processing record 21 of Set 11 | cherskiy
# Processing record 22 of Set 11 | kutum
# Processing record 23 of Set 11 | fairbanks
# Processing record 24 of Set 11 | karratha
# Processing record 25 of Set 11 | brigantine
# Processing record 26 of Set 11 | minab
# Processing record 27 of Set 11 | king city
# Processing record 28 of Set 11 | komsomolets
# Processing record 29 of Set 11 | mason city
# Processing record 30 of Set 11 | gornozavodsk
# Processing record 31 of Set 11 | madaba
# Processing record 32 of Set 11 | tual
# Processing record 33 of Set 11 | los llanos de aridane
# Processing record 34 of Set 11 | jiayuguan
# Processing record 35 of Set 11 | fort smith
# Processing record 36 of Set 11 | helong
# Processing record 37 of Set 11 | zhigansk
# Processing record 38 of Set 11 | janauba
# Processing record 39 of Set 11 | fayaoue
# Processing record 40 of Set 11 | tchollire
# Processing record 41 of Set 11 | axim
# Processing record 42 of Set 11 | christchurch
# Processing record 43 of Set 11 | luderitz
# Processing record 44 of Set 11 | changde
# Processing record 45 of Set 11 | mporokoso
# Processing record 46 of Set 11 | nkowakowa
# Processing record 47 of Set 11 | florianopolis
# Processing record 48 of Set 11 | palana
# Processing record 49 of Set 11 | gijon
# Processing record 50 of Set 11 | lagos
# Processing record 1 of Set 12 | elko
# Processing record 2 of Set 12 | huntingdon
# Processing record 3 of Set 12 | pimentel
# Processing record 4 of Set 12 | kindu
# Processing record 5 of Set 12 | mugumu
# Processing record 6 of Set 12 | voh
# Processing record 7 of Set 12 | gallup
# Processing record 8 of Set 12 | biak
# Processing record 9 of Set 12 | buala
# Processing record 10 of Set 12 | kruisfontein
# Processing record 11 of Set 12 | yuzhno-kurilsk
# Processing record 12 of Set 12 | nemuro
# Processing record 13 of Set 12 | tomatlan
# Processing record 14 of Set 12 | ketchikan
# Processing record 15 of Set 12 | udachnyy
# Processing record 16 of Set 12 | buhl
# Processing record 17 of Set 12 | blonduos
# city not found.  Skipping...
# Processing record 18 of Set 12 | kulhudhuffushi
# Processing record 19 of Set 12 | boa esperanca
# Processing record 20 of Set 12 | kijang
# Processing record 21 of Set 12 | quatre cocos
# Processing record 22 of Set 12 | bagaha
# Processing record 23 of Set 12 | togur
# Processing record 24 of Set 12 | portmore
# Processing record 25 of Set 12 | kovur
# Processing record 26 of Set 12 | labutta
# city not found.  Skipping...
# Processing record 27 of Set 12 | kostyantynivka
# Processing record 28 of Set 12 | townsville
# Processing record 29 of Set 12 | chusovoy
# Processing record 30 of Set 12 | ewo
# Processing record 31 of Set 12 | sao desiderio
# Processing record 32 of Set 12 | matamoros
# Processing record 33 of Set 12 | torbay
# Processing record 34 of Set 12 | kupang
# Processing record 35 of Set 12 | glenwood springs
# Processing record 36 of Set 12 | launceston
# Processing record 37 of Set 12 | imbituba
# Processing record 38 of Set 12 | bara
# Processing record 39 of Set 12 | belaya gora
# Processing record 40 of Set 12 | lamu
# Processing record 41 of Set 12 | nibbar
# Processing record 42 of Set 12 | nuuk
# Processing record 43 of Set 12 | kontagora
# Processing record 44 of Set 12 | taltal
# Processing record 45 of Set 12 | odemira
# Processing record 46 of Set 12 | we
# city not found.  Skipping...
# Processing record 47 of Set 12 | scarborough
# Processing record 48 of Set 12 | yangambi
# Processing record 49 of Set 12 | sento se
# city not found.  Skipping...
# Processing record 50 of Set 12 | oxford
# Processing record 1 of Set 13 | vao
# Processing record 2 of Set 13 | adrar
# Processing record 3 of Set 13 | tabou
# Processing record 4 of Set 13 | pucallpa
# Processing record 5 of Set 13 | sangar
# Processing record 6 of Set 13 | cartagena
# Processing record 7 of Set 13 | kamenskoye
# city not found.  Skipping...
# Processing record 8 of Set 13 | gambela
# Processing record 9 of Set 13 | decatur
# Processing record 10 of Set 13 | aakirkeby
# city not found.  Skipping...
# Processing record 11 of Set 13 | velikiy ustyug
# Processing record 12 of Set 13 | upata
# Processing record 13 of Set 13 | aquiraz
# Processing record 14 of Set 13 | walvis bay
# Processing record 15 of Set 13 | mahoba
# Processing record 16 of Set 13 | dhidhdhoo
# Processing record 17 of Set 13 | takoradi
# Processing record 18 of Set 13 | akyab
# Processing record 19 of Set 13 | avera
# Processing record 20 of Set 13 | moerai
# Processing record 21 of Set 13 | khandyga
# Processing record 22 of Set 13 | poum
# Processing record 23 of Set 13 | inyonga
# Processing record 24 of Set 13 | geresk
# city not found.  Skipping...
# Processing record 25 of Set 13 | terekli-mekteb
# Processing record 26 of Set 13 | santa cruz
# Processing record 27 of Set 13 | la baule-escoublac
# Processing record 28 of Set 13 | chara
# Processing record 29 of Set 13 | tamandare
# Processing record 30 of Set 13 | karmala
# Processing record 31 of Set 13 | broome
# Processing record 32 of Set 13 | kulebaki
# Processing record 33 of Set 13 | wajir
# Processing record 34 of Set 13 | ahuimanu
# Processing record 35 of Set 13 | te anau
# Processing record 36 of Set 13 | solwezi
# Processing record 37 of Set 13 | nantucket
# Processing record 38 of Set 13 | edd
# Processing record 39 of Set 13 | shcherbynivka
# Processing record 40 of Set 13 | barstow
# Processing record 41 of Set 13 | xihe
# Processing record 42 of Set 13 | clyde river
# Processing record 43 of Set 13 | isangel
# Processing record 44 of Set 13 | faya
# Processing record 45 of Set 13 | sisimiut
# Processing record 46 of Set 13 | burgeo
# Processing record 47 of Set 13 | khorixas
# Processing record 48 of Set 13 | sao felix do xingu
# Processing record 49 of Set 13 | derzhavinsk
# Processing record 50 of Set 13 | truth or consequences
# Processing record 1 of Set 14 | port augusta
# Processing record 2 of Set 14 | makokou
# Processing record 3 of Set 14 | bilma
# Processing record 4 of Set 14 | jijiga
# Processing record 5 of Set 14 | san felipe
# Processing record 6 of Set 14 | gao
# Processing record 7 of Set 14 | roma
# Processing record 8 of Set 14 | tres coracoes
# Processing record 9 of Set 14 | shirokiy
# Processing record 10 of Set 14 | kattivakkam
# Processing record 11 of Set 14 | mogadishu
# Processing record 12 of Set 14 | chicama
# Processing record 13 of Set 14 | singkawang
# Processing record 14 of Set 14 | mazagao
# Processing record 15 of Set 14 | pathein
# Processing record 16 of Set 14 | todos santos
# Processing record 17 of Set 14 | yara
# Processing record 18 of Set 14 | san luis
# Processing record 19 of Set 14 | bay roberts
# Processing record 20 of Set 14 | nhulunbuy
# Processing record 21 of Set 14 | ogaminana
# Processing record 22 of Set 14 | dehui
# Processing record 23 of Set 14 | pandan
# Processing record 24 of Set 14 | karlskrona
# Processing record 25 of Set 14 | khandbari
# Processing record 26 of Set 14 | lahat
# Processing record 27 of Set 14 | kazalinsk
# city not found.  Skipping...
# Processing record 28 of Set 14 | boyolangu
# Processing record 29 of Set 14 | russell
# Processing record 30 of Set 14 | boende
# Processing record 31 of Set 14 | maragogi
# Processing record 32 of Set 14 | wawa
# Processing record 33 of Set 14 | general pico
# Processing record 34 of Set 14 | kavieng
# Processing record 35 of Set 14 | olinda
# Processing record 36 of Set 14 | garmsar
# Processing record 37 of Set 14 | tiznit
# Processing record 38 of Set 14 | kaduqli
# Processing record 39 of Set 14 | neryungri
# Processing record 40 of Set 14 | margate
# Processing record 41 of Set 14 | rungata
# city not found.  Skipping...
# Processing record 42 of Set 14 | gigmoto
# Processing record 43 of Set 14 | miranorte
# city not found.  Skipping...
# Processing record 44 of Set 14 | kampong thum
# Processing record 45 of Set 14 | smithers
# Processing record 46 of Set 14 | ranong
# Processing record 47 of Set 14 | ambon
# Processing record 48 of Set 14 | palmer
# Processing record 49 of Set 14 | schenectady
# Processing record 50 of Set 14 | maryville
# Processing record 1 of Set 15 | elizabethton
# Processing record 2 of Set 15 | luxor
# Processing record 3 of Set 15 | gamba
# Processing record 4 of Set 15 | chikoy
# city not found.  Skipping...
# Processing record 5 of Set 15 | shasta lake
# Processing record 6 of Set 15 | arona
# Processing record 7 of Set 15 | lokosovo
# Processing record 8 of Set 15 | vaitape
# Processing record 9 of Set 15 | nova olimpia
# Processing record 10 of Set 15 | fonte boa
# Processing record 11 of Set 15 | shiraz
# Processing record 12 of Set 15 | daru
# Processing record 13 of Set 15 | chilca
# Processing record 14 of Set 15 | tobane
# Processing record 15 of Set 15 | sakharovo
# Processing record 16 of Set 15 | sarangani
# Processing record 17 of Set 15 | guayanilla
# Processing record 18 of Set 15 | beloha
# Processing record 19 of Set 15 | mountain home
# Processing record 20 of Set 15 | suao
# city not found.  Skipping...
# Processing record 21 of Set 15 | luanda
# Processing record 22 of Set 15 | tarauaca
# Processing record 23 of Set 15 | kiama
# Processing record 24 of Set 15 | port hueneme
# Processing record 25 of Set 15 | camacha
# Processing record 26 of Set 15 | monroe
# Processing record 27 of Set 15 | abbeville
# Processing record 28 of Set 15 | ust-barguzin
# Processing record 29 of Set 15 | puerto ayacucho
# Processing record 30 of Set 15 | ruteng
# Processing record 31 of Set 15 | guerrero negro
# Processing record 32 of Set 15 | komsomolskiy
# Processing record 33 of Set 15 | sao joao da barra
# Processing record 34 of Set 15 | coihaique
# Processing record 35 of Set 15 | danville
# Processing record 36 of Set 15 | balkanabat
# Processing record 37 of Set 15 | bud
# Processing record 38 of Set 15 | thilogne
# city not found.  Skipping...
# Processing record 39 of Set 15 | takhli
# Processing record 40 of Set 15 | cervo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data[50]
# Out:
# {'City': 'Winchester',
#  'Lat': 51.0651,
#  'Lng': -1.3187,
#  'Max Temp': 65.77,
#  'Humidity': 79,
#  'Cloudiness': 40,
#  'Wind Speed': 1.01,
#  'Weather Description': 'scattered clouds',
#  'Country': 'GB',
#  'Date': '2021-09-23 18:22:58'}

# %%
len(city_data)
# Out:
# 694

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bredasdorp      ZA -34.5322   20.0403     60.28        67          54
# 1           Bluff      NZ -46.6000  168.3333     47.80        63          42
# 2  Port Elizabeth      ZA -33.9180   25.5701     65.10        67           0
# 3        Altamira      BR  -3.2033  -52.2064     93.29        55          75
# 4        Hermanus      ZA -34.4187   19.2345     60.80        84          36
#
#    Wind Speed Weather Description
# 0       14.97       broken clouds
# 1       26.82    scattered clouds
# 2       24.16           clear sky
# 3        8.05       broken clouds
# 4       14.81    scattered clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
